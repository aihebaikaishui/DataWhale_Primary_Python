# %% [markdown]
# ## 画图种类
# * ### Scatter 散点图
# * ### Bar柱状图
# * ### Contours 等高线图
# * ### Image 图片

# %% [markdown]
# ### Scatter 散点图
# 生成1024个呈标准正态分布的二维数据组 (平均数是0，方差为1) 作为一个数据集，并图像化这个数据集。每一个点的颜色值用T来表示：

# %%
# 导入数据
import matplotlib.pyplot as plt
import numpy as np

n = 1024    # data size
X = np.random.normal(0, 1, n)
Y = np.random.normal(0, 1, n)
T = np.arctan2(Y, X)    # for color later on

plt.scatter(X, Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.xticks(())  # ignore xticks
plt.ylim(-1.5, 1.5)
plt.yticks(())  # ignore yticks

plt.show()

# %% [markdown]
# ### 柱状图Bar
# * #### 生成基本图形
# * #### 加颜色和数据

# %%
# 向上向下分别生成12个数据，X为 0 到 11 的整数 ，Y是相应的均匀分布的随机数据。 使用的函数是plt.bar，参数为X和Y：
import matplotlib.pyplot as plt
import numpy as np

n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X, +Y1)
plt.bar(X, -Y2)

plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25, 1.25)
plt.yticks(())

#plt.show()
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
# 加颜色和数据
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
#plt.show()
# Out:
# <BarContainer object of 12 artists>

# %%
# 加数值，（包括格式设置）
# 承前
import matplotlib.pyplot as plt
import numpy as np

n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X, +Y1)
plt.bar(X, -Y2)

plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25, 1.25)
plt.yticks(())
# 加颜色和数据
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
#plt.show()
for x, y in zip(X, Y1):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='center', va='bottom')

for x, y in zip(X, Y2):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x + 0.4, -y - 0.05, '%.2f' % y, ha='center', va='top')

# %% [markdown]
# # Contours等高线图
# * ### 画等高线
# * ### 添加高度数字

# %% [markdown]
# ### 最后的效果图
# ![等高线](https://morvanzhou.github.io/static/results/plt/3_3_1.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 定义x, y 以及高度函数
def f(x,y):
    # the height function
    return (1 - x / 2 + x**5 + y**3) * np.exp(-x**2 -y**2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x, y)  # 编织成栅格

# 颜色填充——plt.contourf
plt.contourf(X,Y,f(X,Y),8,alpha = 0.75, cmap = plt.cm.hot) # cmp = colormap ,alpha是透明度
C=plt.contour(X,Y,f(X,Y),8,colors = 'black',lw=0.5)    # 只有颜色和线条还没有数字
C=plt.clabel(C,inline=True,fontsize=10)  # inline控制是否将label画在线里面，，fontsize 字体大小为10
plt.xticks(())  #取消x轴ticks 
plt.yticks(())  #取消y轴ticks
plt.show()

# %% [markdown]
# ### Image 图片
# * #### 随机矩阵画图
# * #### 出图方式
# * #### colorbar

# %% [markdown]
# ![the conclusion](https://morvanzhou.github.io/static/results/plt/3_4_1.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)
# 出图
plt.imshow(a, interpolation='nearest', cmap='bone', origin='lower')  # 插值方式，内插法；origin='lower'与origin = 'upper'对应，黑白位置

#colorbar
plt.colorbar(shrink=.92)  #将colorbar变为原来的0.92

plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# ### 插图方式
# ![](https://morvanzhou.github.io/static/results/plt/3_4_2.png)

# %% [markdown]
# ### 3D数据
# * #### 3D图
# * #### 投影

# %% [markdown]
# ![结果图](https://morvanzhou.github.io/static/results/plt/3_5_1.png)

# %%
# 引入Axes 3D模块
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
# 定义图像窗口，并添加3D坐标轴
fig = plt.figure()
ax=Axes3D(fig)

# %%
# 引入Axes 3D模块
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
# 定义图像窗口，并添加3D坐标轴
fig = plt.figure()
ax=Axes3D(fig)
# 给XY赋值，并绘制成栅格。每一个（X,Y）点对应的高度值
# X, Y value
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)    # x-y 平面的网格
R = np.sqrt(X ** 2 + Y ** 2)
# height value
Z = np.sin(R)
#做出一个三维曲面，并将一个 colormap rainbow 填充颜色，之后将三维图像投影到 XY 平面上做一个等高线图。 plot 3D 图像：
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))# ，rstride 和 cstride 分别代表 row 和 column 的跨度。
# 投影
# 添加x Y 平面的等高线
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.get_cmap('rainbow'))
plt.show()

# %% [markdown]
# ### Animation动画
# * #### 定义方程
# * #### 参数设置

# %%
from matplotlib import pyplot as plt
from matplotlib import animation
import numpy as np
fig, ax = plt.subplots()
# 定义数据：正弦曲线
x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))

#构造自定义动画函数animate，用来更新每一帧上各个x对应的y坐标值，参数表示第i帧：
def animate(i):
    line.set_ydata(np.sin(x + i/10.0))
    return line,
# 构造开始帧函数init：
def init():
    line.set_ydata(np.sin(x))
    return line,

#调用FuncAnimation函数生成动画
ani = animation.FuncAnimation(fig=fig,
                              func=animate,
                              frames=100,
                              init_func=init,
                              interval=20,  #每20ms更新一次
                              blit=False)  #只更新变化的点还是全部更新（false）
# 显示动画
plt.show()
