# %% [markdown]
# * #### 绘制y=x+1的图线。要求：-1<x<2.线条类型'--'宽度：1.5；颜色：'red'
# * #### 坐标轴命名'I am X/Y' 赋予x/y 5个刻度，每个刻度都命名。
# * #### 调整刻度的位置，调整坐标轴的位置

# %% [markdown]
# #### 想要再次显示上一次的plt怎么办? 即plt.show()之后，plt上的那些还能再show一遍吗？

# %% [markdown]
# 0526 复习
# 利用matplotlib绘制图像，要考虑哪些对象？
# import matplotlib.pyplot as plt
# plt.figure() # 创建了一个图像窗口
# 基本内容：比如 x= np.linspace(-1,1,50)  y=x+1  plt.plot(x,y)
# 简单修饰：颜色、粗细/线型
#
# 附加内容：
# 坐标轴axis身上那些元素：(以x轴为例)
# 名字：xlabel('I am x')
# 定义域：xlim((1,2))
# 刻度:ticks 画勾 plt.xticks(new_ticks)  # 提前定义new_ticks = np.linspace(-1,2,5)
# 给每一个刻度点命名：plt.yticks([-1,-0.4,4],[r'$really\ bad$', r'$bad$',r'$normal$'])
# 型
#
# 位置：spines脊椎骨
# 需要先获取坐标轴当前的全部信息。。get current axis 即plot.gca()
# ax = plt.gca()  ax.spines['right'].set_color('none')
# 调整位置：刻度位置ax.xaxis.set_ticks_position('bottom')
# axis位置：ax.spine['bottom'].set_position(('data',0))

# %% [markdown]
# ## 基本用法

# %% [markdown]
# 使用plt.figure定义一个图像窗口. 使用plt.plot画(x ,y)曲线. 使用plt.show显示图像.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-1,1,50)
y= 2*x+1
plt.figure()
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## figure图像
# ### 简单的线条
# #### figure就是一个单独的小窗口，里面可以画出多条图线

# %%
#使用plt.figure定义一个图像窗口：编号为3；大小为(8, 5).
#使用plt.plot画(x ,y2)曲线. 使用plt.plot画(x ,y1)曲线，
#曲线的颜色属性(color)为红色;曲线的宽度(linewidth)为1.0；曲线的类型(linestyle)为虚线.
#使用plt.show显示图像.
x=np.linspace(-3,3,50)
y1 = 2*x+1
y2=x**2
plt.figure(num=3,figsize=(8,5))
plt.plot(x,y1,color = 'red',linewidth=1.0,linestyle='--')
plt.plot(x,y2)
plt.show()
plt.plot(x,y2)
plt.plot(x,y1)
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## 插曲：关键字参数。（上面用到了）
# 关键字参数可以传入0个或者任意个含参数名的参数，这些参数名在函数定义中并没有出现，这些参数在函数内部自动封装成一个字典(dict).

# %%
# 函数定义
def portrait(name,**kw):
    print('name is',name)
    for k,v in kw.items(): #k 代表字典中的key，while v 代表dict中的value.而kw.item()则代表一个个的键值对 
        print(k,v)

# %%
#函数调用
portrait('Mike',age=24,country = 'China',education = 'bachelor')
# Out:
# name is Mike
# age 24
# country China
# education bachelor

# %% [markdown]
# -----

# %% [markdown]
# ## 设置坐标轴
# * ### 调整名字和间隔
# * ### 设置不同名字和位置
# * ### 调整坐标轴

# %% [raw]
# ### 关键方法
# * ### xlim((1,2))
# * ### ylabel('I am x')
# * ### xticks(new_ticks)...e.g., new_ticks = np.linspace(-1,2,5)
# * ### xaxis.set_ticks_position
# * ### ax.spines[].set_position((,))

# %%
# 承上
x=np.linspace(-3,3,50)
y1 = 2*x+1
y2=x**2
plt.figure(num=3,figsize=(8,5))
plt.plot(x,y1,color = 'red',linewidth=1.0,linestyle='--')
plt.plot(x,y2)
plt.show() # show完之后plt对象将被释放
# 需要再次plot一遍
plt.plot(x,y1,color = 'red',linewidth=1.0,linestyle='--')
plt.plot(x,y2)
# 给坐标轴添加名称和limit长度
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('I am x')
plt.ylabel('I am Y')
# 给坐标轴做分隔
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks=\n',new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])
plt.show()
# Out:
# new_ticks=
#  [-1.   -0.25  0.5   1.25  2.  ]

# %% [markdown]
# 使用plt.gca获取当前坐标轴信息.
# 使用.spines设置边框：右侧边框；使用.set_color设置边框颜色：默认白色；
# 使用.spines设置边框：上边框；使用.set_color设置边框颜色：默认白色；

# %%
# 承上
x=np.linspace(-3,3,50)
y1 = 2*x+1
y2=x**2
plt.plot(x,y1,color = 'red',linewidth=1.0,linestyle='--')
plt.plot(x,y2)
#plt.show()
# 给坐标轴添加名称和limit长度
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('I am x')
plt.ylabel('I am Y')
# 给坐标轴做分隔
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks=\n',new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])
plt.show()
# 设置不同名字和位置
#前面的再来一遍
plt.plot(x,y1,color = 'red',linewidth=1.0,linestyle='--')
plt.plot(x,y2)
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('I am x')
plt.ylabel('I am Y')
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks=\n',new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])
# 先获取坐标对象
ax = plt.gca()  #获取当前坐标信息
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')
plt.show()
# Out:
# new_ticks=
#  [-1.   -0.25  0.5   1.25  2.  ]
# new_ticks=
#  [-1.   -0.25  0.5   1.25  2.  ]

# %%
# 承上并调整坐标位置以及修饰边框
#前面的再来一遍
plt.plot(x,y1,color = 'red',linewidth=1.0,linestyle='--')
plt.plot(x,y2)
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('I am x')
plt.ylabel('I am Y')
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks=\n',new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])
# 先获取坐标对象
ax = plt.gca()  #获取当前坐标信息
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')
# 
ax.xaxis.set_ticks_position('bottom')   # 指明谁是x轴  #  所有位置：top，bottom，both，default，none
ax.spines['bottom'].set_position(('data', 0))   #spine边框，x轴的位置 依据data来选择# 可选参数 (outward, axes, data)
#plt.show() 
ax.yaxis.set_ticks_position('left')  
ax.spines['left'].set_position(('data',0))
plt.show()
# Out:
# new_ticks=
#  [-1.   -0.25  0.5   1.25  2.  ]

# %% [markdown]
# ---

# %% [markdown]
# ## Legend图例
# * ### 添加默认图例
# * ### 调整位置和名称

# %%
# 承上
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 50)
y1 = 2*x + 1
y2 = x**2

plt.figure()
#set x limits
plt.xlim((-1, 2))
plt.ylim((-2, 3))

# set new sticks
new_sticks = np.linspace(-1, 2, 5)
plt.xticks(new_sticks)
# set tick labels
plt.yticks([-2, -1.8, -1, 1.22, 3],
           [r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])
# 启下
# set line syles
l1, = plt.plot(x, y1, label='linear line')  # 以,结尾是因为plot返回的是一个list
l2, = plt.plot(x, y2, color='red', linewidth=1.0, linestyle='--', label='square line')
#加legend
#调整位置和名称
plt.legend(handles=[l1, l2], labels=['up', 'down'],  loc='best')
plt.show()
#plt.legend(loc='upper right')
#plt.show()

# %%
#调整位置和名称
#给不同类型的线条设置图例信息
plt.legend(handles=[l1, l2], labels=['up', 'down'],  loc='best')
plt.show()

# %% [markdown]
# 其中’loc’参数有多种，’best’表示自动分配最佳位置，其余的如下：
#  'best' : 0,
#  'upper right'  : 1,
#  'upper left'   : 2,
#  'lower left'   : 3,
#  'lower right'  : 4,
#  'right'        : 5,
#  'center left'  : 6,
#  'center right' : 7,
#  'lower center' : 8,
#  'upper center' : 9,
#  'center'       : 10,

# %% [markdown]
# ----

# %%
## Annotation 标注
* ### 画出基本图
* ### 移动坐标
* ### 添加标注 annotate
* ### 添加注释 text

# %% [markdown]
# #### 效果图如下
# ![annotation](https://morvanzhou.github.io/static/results/plt/2_6_5.png)

# %%
# 画出基本图
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 50)
y = 2*x + 1

plt.figure(num=1, figsize=(8, 5),)
plt.plot(x, y,)

# 移动坐标轴位置
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

#标注出点(x0,y0)的位置信息。用plt.plot([x0,x0,],[0,y0,],'K--',linewidth = 2.5)画出一条垂直于x轴的虚线
x0 = 1
y0 = 2*x0 + 1
plt.plot([x0, x0,], [0, y0,], 'k--', linewidth=2.5)  #
# set dot styles
plt.scatter([x0, ], [y0, ], s=50, color='b')  #s是什么？

# 添加注释annotate
#xycoords:基于数据的值来选位置；
    # xytext=(+30, -30) 和 textcoords='offset points' 对于标注位置的描述 和 xy 偏差值,
    # arrowprops是对图中箭头类型的一些设置.
    # xytext=(+30, -30) 和 textcoords='offset points' 对于标注位置的描述 和 xy 偏差值, 
    # arrowprops是对图中箭头类型的一些设置.
plt.annotate(r'$2x+1=%s$' % y0, xy=(x0, y0), xycoords='data', xytext=(+30, -30),
             textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle='->', connectionstyle="arc3,rad=.2"))
# 添加注释text
# 其中-3.7, 3,是选取text的位置, 空格需要用到转字符\ ,fontdict设置文本字体.
plt.text(-3.7, 3, r'$This\ is\ the\ some\ text. \mu\ \sigma_i\ \alpha_t$',
         fontdict={'size': 16, 'color': 'r'})
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## tick 能见度
# * ### 生成图形
# * ### 调整坐标

# %% [markdown]
# #### 当图片中的内容较多，相互遮盖时，我们可以通过设置相关内容的透明度来使图片更易于观察，参数 bbox

# %%
# 承前
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 50)
y = 0.1*x

plt.figure()
# 在 plt 2.0.2 或更高的版本中, 设置 zorder 给 plot 在 z 轴方向排序
plt.plot(x, y, linewidth=10, zorder=1)
plt.ylim(-2, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# %%
# 承前
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 50)
y = 0.1*x

plt.figure()
# 在 plt 2.0.2 或更高的版本中, 设置 zorder 给 plot 在 z 轴方向排序
plt.plot(x, y, linewidth=10, zorder=1)
plt.ylim(-2, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))
# 调节相关透明度
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
    # 在 plt 2.0.2 或更高的版本中, 设置 zorder 给 plot 在 z 轴方向排序
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.7, zorder=2))
plt.show()
